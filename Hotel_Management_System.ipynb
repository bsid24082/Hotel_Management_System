# %% [markdown]
# <a href="https://colab.research.google.com/github/bsid24082/Hotel_Management_System/blob/main/Hotel_Management_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import random
import pandas as pd
from IPython.display import display

# %%
## Declaring the Lists to store Seperate Data required by the Hotel
name = []
phone_no = []
address = []
check_in = []
check_out = []
room = []
price = []
room_no = []
cust_id = []
Num_days = []
rc = []
p = []
r = []
total_rc = []

# %%
def date(c):
  if c[2] >= 2023 and c[2] < 2024:
    if c[1] > 0 and c[1] <= 12:
      if c[1] == 2 and c[0] != 0 and c[0] <= 31:
        if c[2]%4 == 0 and c[0]<=29:
          pass
        elif c[0]<29:
          pass
        else:
          print("Invalid Date")
          name.pop(i)
          phone_no.pop(i)
          address.pop(i)
          check_in.pop(i)
          check_out.pop(i)
          Booking()

      elif c[1] <= 7 and c[1]%2 != 0 and c[0] <= 31:
        pass
      elif c[1] <= 7 and c[1]%2 == 0 and c[0] <= 30 and c[1] != 2:
        pass
      elif c[1] >= 8 and c[1]%2 == 0 and c[0] <= 30:
        pass
      elif c[1] >= 8 and c[1]%2 != 0 and c[0] <= 31:
        pass
      else:
        print("Invalid Date")
        name.pop(i)
        phone_no.pop(i)
        address.pop(i)
        check_in.pop(i)
        check_out.pop(i)
        Booking()
    else:
      print("Invalid Date")
      name.pop(i)
      phone_no.pop(i)
      address.pop(i)
      check_in.pop(i)
      check_out.pop(i)
      Booking()
  else:
    print("Invalid Date")
    name.pop(i)
    phone_no.pop(i)
    address.pop(i)
    check_in.pop(i)
    check_out.pop(i)
    Booking()

# %%
def Booking():
  chk_in = str(input(" Check-In Date(DD-MM-2023) : "))
  check_in.append(chk_in)
  chk_in = chk_in.split('-')
  ck_in = chk_in
  ck_in[0]=int(ck_in[0])
  ck_in[1]=int(ck_in[1])
  ck_in[2]=int(ck_in[2])
  date(ck_in)

  chk_out = str(input("Check-Out Date(DD/MM/2023) : "))
  check_out.append(chk_out)
  chk_out = chk_out.split("-")
  ck_out = chk_out
  ck_out[0]=int(ck_out[0])
  ck_out[1]=int(ck_out[1])
  ck_out[2]=int(ck_out[2])
  date(ck_out)

    ## To check if the check-out date doesnt fall before the checkin date
  if(ck_out[1] < ck_in[1] and ck_out[2] < ck_in[2]):
    print("*******Oops!! The Check-Out Date you have selected is Invalid, Select a date that comes after the Check-in Date*******")
    name.pop(i)
    address.pop(i)
    check_in.pop(i)
    check_out.pop(i)
    Booking()

  elif(ck_out[1] == ck_in[1] and ck_out[2] >= ck_in[2] and ck_out[0] <= ck_in[0]):
    name.pop(i)
    address.pop(i)
    check_in.pop(i)
    check_out.pop(i)
    Booking()

  else:
    pass
  date(ck_out)
  d1 = datetime.datetime(ck_in[2], ck_in[1], ck_in[0])
  d2 = datetime.datetime(ck_out[2], ck_out[1], ck_out[0])
  d = (d2-d1).days
  Num_days.append(d)

  print("----------SELECT ROOM OF YOUR CHOICE----------")
  print(" 1) Standard Dormitory Non-AC ")
  print(" 2) Standard Non-AC ")
  print(" 3) Deluxe Non-AC")
  print(" 4) Deluxe AC")
  print(" 5) Master Suite AC")
  print("\t\t Press 0 to know more about the Room-Prices ")

  ch = int(input("Pick the room for your stay --> "))

  if ch == 0:
    print(" 1) Standard Dormitory Non-AC - Rs 750 ")
    print(" 2) Standard Non-AC           - Rs 1200")
    print(" 3) Deluxe Non-AC             - Rs 1750")
    print(" 4) Deluxe AC                 - Rs 2500")
    print(" 5) Master Suite AC           - Rs 3750")
    ch = int(input("Pick the room for your stay --> "))

  elif ch == 1:
    room.append(" Standard Dormitory Non-AC ")
    print("----Your Choce of Room----")
    print("Your Choice - Standard Dormitory Non-AC ")
    price.append(750)
    print("Price - Rs 750")

  elif ch == 2:
    room.append(" Standard Non-AC ")
    print("----Your Choce of Room----")
    print("Your Choice - Standard  Non-AC ")
    price.append(1200)
    print("Price - Rs 1200")

  elif ch == 3:
    room.append(" Deluxe Non-AC ")
    print("----Your Choce of Room----")
    print("Your Choice - Deluxe Non-AC ")
    price.append(1750)
    print("Price - Rs 1750")

  elif ch == 4:
    room.append(" Deluxe AC ")
    print("----Your Choce of Room----")
    print("Your Choice - Deluxe AC ")
    price.append(2500)
    print("Price - Rs 2500")

  elif ch == 5:
    room.append(" Master Suite Ac ")
    print("----Your Choce of Room----")
    print("Your Choice - Master Suite AC ")
    price.append(3750)
    print("Price - Rs 3750")

  else:
    print("*******OOPS!! YOU PICKED THE WRONG OPTION, TRY AGAIN*******")

  print(" *******Information required for Booking******* ")
  print("")
  print("")

  na = str(input("Enter your Name: "))
  ph = str(input("Enter your Contact Number: "))
  add = str(input("Enter your Current Permanent Address: "))




    ## GENERATING RANDOM ROOM NUMBERS
  rn = random.randrange(40) + 300
  cid = random.randrange(40) + 10

  while rn in room_no or cid in cust_id:
    rn = random.randrange(60)+300
    cid = random.randrange(60)+10

  # rc.append(0)
  p.append(0)
  n = len(phone_no)

  if(ph not in phone_no):
    if(na != "" and ph != "" and add!= ""):
      name.append(na)
      address.append(add)
      phone_no.append(ph)
  else:
    n = phone_no.index(ph)
    print("")
    if p[n] == 0:
      print("\tPhone number already exists and the Payment is pending.......!!")
      name.pop(n)
      address.pop(n)
      check_in.pop(n)
      check_out.pop()
      Booking()
  print("")
  print("\t\t\t **** YOU'RE ROOM IS BOOKED SUCCESSFULLY..HURRAH!!")
  print()
  print("THANKS FOR CHOOSING CHRIST LODGING HOPE YOU ENJOY YOUR STAY HERE....")
  print(" YOUR ROOM NUMBER IS --> ", rn)
  print("YOUR CUSTOMER ID IS --> ", cid)
  room_no.append(rn)
  cust_id.append(cid)
  n = int(input(" 0 - Back \n --> "))
  if n == 0:
    Christ_Lodging()
  else:
    exit()

# %%
# Room Information

def Rooms_Info():
    print("---------- CHRIST LODGING ROOMS INFORMATION ----------")
    print()
    print()
    print("---Standard Dormitory Non-AC---")
    print("----------------------------------------------------------------------------------------------------------")
    print("Room amenities include: 1 Single Bed, Television, Charging Ports")
    print("Telephone, Wardrobe, 1 Coffee Table, Balcony and attached Washrooms to be shared between 3 people")
    print("----------------------------------------------------------------------------------------------------------")
    print()
    print("---Standard Non-AC---")
    print("Room amenities include: 1 Double Bed, Television, Charging Ports")
    print("Telephone, Wardrobe, 1 Coffee Table, Balcony and attached Private Washroom")
    print("----------------------------------------------------------------------------------------------------------")
    print()
    print("---Deluxe Non-AC---")
    print("Room amenities include: 1 Double Bed, Television, Charging Ports")
    print("Telephone, Wardrobe, 2 Coffee Tables, Balcony facing the Lake and attached Private Washroom with Bathtub")
    print("----------------------------------------------------------------------------------------------------------")
    print()
    print("---Deluxe AC---")
    print("Room amenities include: 1 Double Bed, Television, Charging Ports, Centralised Air-Conditioner")
    print("Telephone, Wardrobe, 2 Coffee Tables, Balcony facing the Lake and attached Private Washroom with Bathtub")
    print("----------------------------------------------------------------------------------------------------------")
    print()
    print("---Master Suite AC---")
    print("Room amenities include: 2 Double Beds, Television, Charging Ports, Centralised Air-Conditioner")
    print("Telephone, 2 Wardrobes, 2 Coffee Tables, 2 Balconies facing the Lake and attached Private Washroom with Jacuzi")
    print("----------------------------------------------------------------------------------------------------------")
    print()
    n = int(input(" 0 - Back \n --> "))
    if n == 0:
        Christ_Lodging()
    else:
        exit()

# %%
def Menu_Card():
	fd = int(input("Customer Id: "))
	f = 0
	r = 0
	for n in range(0,len(cust_id)):
		## p is payment status
		if cust_id[n] == fd and p[n] == 0:
			f=1
			print("------------------------------------------------------------------------------")
			print("\t\t\t\t\t\t\t\t\t\t\t\t\t\t\Christ-Lodging")
			print("------------------------------------------------------------------------------")
			print("\t\t\t\t\t\t\t\t\t\t\t\t\t\tMenu-Card")
			print("------------------------------------------------------------------------------")
			print("\n 		**** BEVERAGES *****							 				**** SOUPS ****")
			print("--------------------------------------|---------------------------------------")
			print(" 1) Tea--------------------------- 15 |		8) Brocolli-Almond Soup-------- 200")
			print(" 2) Coffee------------------------ 20 |		9) Creamy Tomato Soup---------- 170")
			print(" 3) Cold-Coffee------------------- 30 |		10) Sweet-Corn Soup------------ 170")
			print(" 4) Lemon-Tea--------------------- 30 |		11) Minestrone Soup------------ 200")
			print(" 5) Cold-Drinks------------------- 30 |		12) Manchow Soup--------------- 170")
			print(" 6) Shakes------------------------ 30 |		13) Pesto Soup----------------- 200")
			print(" 7) Fresh-Juices------------------ 30 |		14) Chicken Soup--------------- 200")
			print("--------------------------------------|---------------------------------------")
			print("\n		 **** Main-Course ****					 |						**** Dessert ****")
			print("--------------------------------------|---------------------------------------")
			print(" 15) Paneer Butter Masala-------- 280 |	 22) Gulab-Jamoooooon------------ 120")
			print(" 16) Paneer Kadhai--------------- 280 | 	 23) Ras-Malai------------------- 120")
			print(" 17) Paneer Bhurji--------------- 280 |	 24) Ice-Cream Sundae------------ 200")
			print(" 18) Veg Kofta------------------- 260 |	 25) Rasgullah------------------- 120")
			print(" 19) Malai Kofta----------------- 280 |	 26) Tiramisu-------------------- 300")
			print(" 20) Aalo Matar------------------ 200 |	 27) Brownie--------------------- 300")
			print(" 21) Jeera Aalo------------------ 200 |	 28) Waffle---------------------- 170")
			print("--------------------------------------|---------------------------------------")
			print("\n		 **** Rotis/Breads ****					 |					**** Dal & Rice ****")
			print("--------------------------------------|---------------------------------------")
			print(" 29) Plain Chapatti--------------- 15 |	 38) Dal- Tadka------------------ 170")
			print(" 30) Butter Chapatti-------------- 20 |	 39) Dal-Fry--------------------- 180")
			print(" 31) Butter Tandoori Roti--------- 30 |	 40) Dal-Makhani----------------- 260")
			print(" 32) Butter Garlic Naan ---------- 50 |	 41) Steam Rice------------------ 120")
			print(" 33) Freshly Baked Sour-Dough----- 50 |	 42) Jeera Rice------------------ 170")
			print(" 34) Butter Naan------------------ 50 |	 43) Veg Pulao------------------- 200")
			print(" 35) Stuffed Naan----------------- 70 |	 44) Veg Biryani----------------- 300")
			print(" 36) Butter Laccha---------------- 50 |	 45) Chicken Biryani------------- 350")
			print(" 37) Ghee Missi Roti-------------- 70 |	 46) Mutton Biryani-------------- 350")
			print("------------------------------------------------------------------------------")
			print("Press 0 to end/cancel your order!")
			print("")
			ch = 1
			while(ch != 0):
				ch = int(input("Enter your choice --> "))
				if ch == 1 or ch == 29:
					rs = 15
					r = r + rs
				elif ch == 2 or ch == 30:
					rs = 20
					r = r + rs
				elif ch >= 3 and ch <=7 or ch == 31:
					rs = 30
					r = r + rs

				elif ch >= 15 and ch <= 17 or ch == 19:
					rs = 280
					r = r + rs

				elif ch == 18 or ch == 40:
					rs = 260
					r = r + rs
				elif ch == 20 or ch == 21 or ch == 8 or ch == 11 or ch ==13 or ch == 14 or ch == 24 or ch == 43:
					rs = 200
					r = r + rs

				elif ch == 32 or ch == 33 or ch == 34 or ch == 36:
					rs = 50
					r = r + rs
				elif ch == 35 or ch == 37:
					rs = 70
					r = r + rs
				elif ch == 9 or ch == 10 or ch == 12 or ch == 28 or ch == 38 or ch == 42:
					rs = 170
					r = r + rs
				elif ch == 22 or ch == 23 or ch == 25 or ch == 41:
					rs = 120
					r = r + rs
				elif ch == 26 or ch == 27 or ch == 44:
					rs = 300
					r = r + rs

				elif ch == 39:
					rs = 180
					r = r + rs

				elif ch == 45 or ch == 46:
					rs = 350
					r = r + rs
				elif ch == 0:
					pass
				else:
					print(" Wrong Choice")
			print("Your Billing Amount is: ", r)
	 		# print("DEBUB:::: ",rc.__str__())
			rc.append(r)
	 		# print("DEBUB:::: ",rc.__str__())

		else:
			pass
	if f == 0:
		print("Invalid Customer ID")
	n = int(input("0-BACK\n --> "))
	if n==0:
		Christ_Lodging()
	else:
		exit()

# %%
def Payment_portal():
  ph = str(input("Phone Number: "))
  f = 0
  for n in range(0,len(phone_no)):
    if ph == phone_no[n]:
      if p[n] == 0:
        f = 1
        print("Payment")
        print("--------------------------------------------------------------------------------------------------------------------")
        print("MODE OF PAYMENT")

        print("1. Use your Credit/Debit Card")
        print("2. Use your Paytm/PhonePe")
        print("3. Use your UPI (Google-pay/Paytm/Bharat-Pay)")
        print("4. Go Cash!!! Give us your Black Money:)")
        x = int(input())
        print("Amount: ",(price[n]*Num_days[n]+rc[n]))
        print("Pay for Christ Lodging")
        print("yes/no")
        ch = str(input())

        if ch == "yes":
          print("------------------------------------------------------------------------------------------------------------------------")
          print("Hotel Christ Lodging")
          print("------------------------------------------------------------------------------------------------------------------------")
          print("Your Total Bill Amount")
          print("------------------------------------------------------------------------------------------------------------------------")
          print("Name: ",name[n],"\t\n Phone No.:",phone_no[n],"\t\n Address: ",address[n],"\t")
          print("\n Check-In Date: ",check_in[n],"\t\n Check-Out Date: ",check_out[n],"\t")
          print("\n Room Type: ",room[n],"\t\n Room Charges: ",price[n]*Num_days[n],"\t")
          print("Restaurant Charges: \t",rc[n])
          print("-------------------------------------------------------------------------------------------------------------------------")
          print("\n Total Amount: ",(price[n]*Num_days[n]+rc[n]))
          print("-------------------------------------------------------------------------------------------------------------------------")
          print("Thank You - Hope you enjoyed your stay at our Lodging")
          print(" We Hope You Visit Again!!!!")
          print("-------------------------------------------------------------------------------------------------------------------------")
          p.pop(n)
          p.insert(n,1)

          room_no.pop(n)
          cust_id.pop(n)
          room_no.insert(n,0)
          cust_id.insert(n,0)
      else:
        for j in range(n+1,i):
          if ph == phone_no[j]:
            if p[j] == 0:
              pass
            else:
              f = 1
              print("Payment has been Processed!!")
              print("Yay!! It was a Success")
              print("You're eligible for 15% discount on our Suite Room on your next Booking.")
  if f == 0:
    print("Invalid Customer ID")
  n = int(input("0-BACK"))
  if n == 0:
    Christ_Lodging()
  else:
    exit()

# %%
def BK_Records():
  if phone_no != []:
    print("HOTEL RECORD")
    print("|Name  |Phone no.  |Address  |Check-In |Check-Out  |Room Type  |Price  |")
    print("------------------------------------------------------------------------------------------------------------------------------")
    for n in range(0,len(name)):
      print("|",name[n],"\t |",phone_no[n],"\t|",address[n],"\t|",check_in[n],"\t|",room[n],"\t|",price[n]*Num_days[n]+rc[n])
    print("--------------------------------------------------------------------------------------------------------------------------------")
  else:
    print("No Records Found")
  n = int(input("0-BACK\n ->"))
  if n == 0:
    Christ_Lodging()
  else:
    exit()

# %%
ifile = open('Booking_Details.csv','w')
ifile.close()

# %%
def addto():
  global name, phone_no, address, check_in, check_out, room, price, room_no, cust_id, Num_days, rc, p
  data = dict({'Name' : name,
               'Phone Number': phone_no,
               'Address' : address,
               'Check In Date' : check_in,
               'Check Out Date': check_out,
               'Room' : room,
               'Price of Room' : price,
               'Room Number' : room_no,
               'Customer ID' : cust_id,
               'Number of days' : Num_days,
               'Restaurant Charges' : rc,
               'Payment Status' : p}
              )

  # Make data frame of above data
  df = pd.DataFrame(data)

  # append data frame to CSV file
  df.to_csv('Booking_Details.csv', mode='a', index=False, header=False)
  n = int(input("0-BACK\n ->"))
  if n == 0:
    Christ_Lodging()
  else:
    exit()

# %%
def Display():
  df = pd.read_csv('Booking_Details.csv')
  display(df)
  n = int(input("0-BACK\n ->"))
  if n == 0:
    Christ_Lodging()
  else:
    exit()

# %%
## Defining the Christ Lodging Services and calling the functions
## that we will define below in the application.
i = 0
def Christ_Lodging():
    print("\t\t\t\t\t\t *******WELCOME TO THE CHRIST-LODGING*******\n")
    print("\t\t\t\t\t\t *******WE BELIEVE IN EXCELLENT SERVICE*******\n")
    print("\t\t\t\t 1) ***Rooms Available at our Lodging***\n")
    print("\t\t\t\t 2) ***To Book a Room***\n")
    print("\t\t\t\t 3) ***Our Menu Card***\n")
    print("\t\t\t\t 4) ***Payment Portal***\n")
    print("\t\t\t\t 5) ***Booking Records***\n")
    print("\t\t\t\t 6) ***Display File***\n")
    print("\t\t\t\t 0) ***Exit***\n")

    ch = int(input("Please select your options --> "))

    if ch == 1:
        print("")
        Rooms_Info()

    elif ch == 2:
        print("")
        Booking()

    elif ch == 3:
        print("")
        Menu_Card()

    elif ch == 4:
        print("")
        Payment_portal()

    elif ch == 5:
        print("")
        BK_Records()

    elif ch == 6:
      print("")
      addto()
      Display()

    else:
        exit()
Christ_Lodging()
# Out:
# 						 *******WELCOME TO THE CHRIST-LODGING*******
#
# 						 *******WE BELIEVE IN EXCELLENT SERVICE*******
#
# 				 1) ***Rooms Available at our Lodging***
#
# 				 2) ***To Book a Room***
#
# 				 3) ***Our Menu Card***
#
# 				 4) ***Payment Portal***
#
# 				 5) ***Booking Records***
#
# 				 6) ***Display File***
#
# 				 0) ***Exit***
#
# Please select your options --> 1
#
# ---------- CHRIST LODGING ROOMS INFORMATION ----------
#
#
# ---Standard Dormitory Non-AC---
# ----------------------------------------------------------------------------------------------------------
# Room amenities include: 1 Single Bed, Television, Charging Ports
# Telephone, Wardrobe, 1 Coffee Table, Balcony and attached Washrooms to be shared between 3 people
# ----------------------------------------------------------------------------------------------------------
#
# ---Standard Non-AC---
# Room amenities include: 1 Double Bed, Television, Charging Ports
# ...
